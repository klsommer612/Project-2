# %%
# Dependencies
import csv
import json

# %%
# Create file paths
csvFilePath = 'data/judge_demographics.csv'
jsonFilePath = 'data/raw_data.json'

# %%
# Create dictionary to store data
data = {}
with open(csvFilePath) as csvFile:
    csvReader = csv.DictReader(csvFile)
    for rows in csvReader:
        print(rows.keys())
# Out:
# ict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])
# odict_keys(['ï»¿Judge ID', 'Race or Ethnicity', 'Gender', 'Court Type'])

# %%
# Create dictionary to store data
data = {}
with open(csvFilePath) as csvFile:
    csvReader = csv.DictReader(csvFile)
    for rows in csvReader:
        id = rows['ï»¿Judge ID']
        data[id] = rows

# %%
# Create new json file and write to it
with open(jsonFilePath, 'w') as jsonFile:
    jsonFile.write(json.dumps(data, indent=4))
